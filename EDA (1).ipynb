# %% [markdown]
# # Analise Exploratoria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('Dados/employee.csv')
pd.set_option('max_columns',35)
dados.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# ...

# %%
dados.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 1465            2061                        3   Male          41
# ...

# %%
dados.sample(5)
# Out:
#       Age Attrition BusinessTravel  DailyRate              Department  \
# 112    54        No     Non-Travel        142         Human Resources
# 1283   28        No  Travel_Rarely       1181  Research & Development
# 927    36        No  Travel_Rarely        429  Research & Development
# 1385   34        No  Travel_Rarely       1239                   Sales
# 482    31       Yes  Travel_Rarely       1365                   Sales
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# 112                 26          3  Human Resources              1
# 1283                 1          3    Life Sciences              1
# 927                  2          4    Life Sciences              1
# 1385                13          4          Medical              1
# 482                 13          4          Medical              1
#
#       EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 112              148                        4  Female          30
# ...

# %%
dados.describe().style.bar(color=['gold'])
# Out:
# <style  type="text/css" >
# ...

# %%
dados.describe().style.background_gradient(cmap='copper')
# Out:
# <style  type="text/css" >
# ...

# %%
dados['Department'].value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
pd.crosstab(dados['EducationField'], dados['Department'])
# Out:
# Department        Human Resources  Research & Development  Sales
# EducationField
# Human Resources                27                       0      0
# Life Sciences                  16                     440    150
# Marketing                       0                       0    159
# Medical                        13                     363     88
# Other                           3                      64     15
# Technical Degree                4                      94     34

# %%
pd.crosstab(dados['EducationField'], dados['Department']).style.bar(color=['gold'])
# Out:
# <style  type="text/css" >
# #T_186721fe_b9f8_11eb_8cdf_485ab6f52454row0_col0,#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row1_col1,#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row0_col1,#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row0_col2,#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row2_col0,#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row2_col1{
#             width:  10em;
#              height:  80%;
#         }#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 59.3%, transparent 59.3%);
#         }#T_186721fe_b9f8_11eb_8cdf_485ab6f52454row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 94.3%, transparent 94.3%);
# ...

# %%
dados.groupby(['Department','JobRole'])[['MonthlyIncome',
                                        'MonthlyRate',
                                        'HourlyRate']].agg(['max',
                                                            'min',
                                                            'mean'])
# Out:
#                                                  MonthlyIncome         \
#                                                            max    min
# Department             JobRole
# Human Resources        Human Resources                   10725   1555
#                        Manager                           19717  14026
# Research & Development Healthcare Representative         13966   4000
#                        Laboratory Technician              7403   1102
#                        Manager                           19999  11244
#                        Manufacturing Director            13973   4011
#                        Research Director                 19973  11031
#                        Research Scientist                 9724   1009
# Sales                  Manager                           19847  11557
#                        Sales Executive                   13872   4001
#                        Sales Representative               6632   1052
#
# ...

# %%
dados.groupby(['Department','JobRole'])[['MonthlyIncome',
                                        'MonthlyRate',
                                        'HourlyRate']].agg(['max',
                                                            'min',
                                                            'mean']).style.background_gradient(
    cmap='copper')
# Out:
# <style  type="text/css" >
# #T_2402e465_b9f8_11eb_b60c_485ab6f52454row0_col0{
#             background-color:  #603d27;
#             color:  #f1f1f1;
#         }#T_2402e465_b9f8_11eb_b60c_485ab6f52454row0_col1,#T_2402e465_b9f8_11eb_b60c_485ab6f52454row3_col2,#T_2402e465_b9f8_11eb_b60c_485ab6f52454row7_col2{
#             background-color:  #0c0805;
#             color:  #f1f1f1;
#         }#T_2402e465_b9f8_11eb_b60c_485ab6f52454row0_col2{
#             background-color:  #20140d;
#             color:  #f1f1f1;
#         }#T_2402e465_b9f8_11eb_b60c_485ab6f52454row0_col3{
#             background-color:  #ffb674;
#             color:  #000000;
# ...
