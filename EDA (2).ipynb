# %% [markdown]
# # Analise Exploratoria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv('Dados/Iris.csv')
dados.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dados.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
dados.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 115  116            6.4           3.2            5.3           2.3
# 67    68            5.8           2.7            4.1           1.0
# 15    16            5.7           4.4            1.5           0.4
# 52    53            6.9           3.1            4.9           1.5
# 68    69            6.2           2.2            4.5           1.5
#
#              Species
# 115   Iris-virginica
# 67   Iris-versicolor
# 15       Iris-setosa
# 52   Iris-versicolor
# 68   Iris-versicolor

# %%
dados.describe().style.bar(color=['gold'])
# Out:
# <style  type="text/css" >
# #T_0a95d677_b9f7_11eb_8d86_485ab6f52454row0_col0,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row0_col1,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row0_col2,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row0_col3,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row0_col4,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 100.0%, transparent 100.0%);
#         }#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row1_col0,#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 50.0%, transparent 50.0%);
#         }#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,gold 3.4%, transparent 3.4%);
#         }#T_0a95d677_b9f7_11eb_8d86_485ab6f52454row1_col2{
#             width:  10em;
# ...

# %%
dados.describe().style.background_gradient(cmap='copper')
# Out:
# <style  type="text/css" >
# #T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row0_col0,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row0_col1,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row0_col2,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row0_col3,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row0_col4,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row7_col0{
#             background-color:  #ffc77f;
#             color:  #000000;
#         }#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row1_col0,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row5_col0{
#             background-color:  #9e6440;
#             color:  #000000;
#         }#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row1_col1,#T_1eeb5b89_b9f7_11eb_9a4a_485ab6f52454row5_col1{
#             background-color:  #0a0604;
#             color:  #f1f1f1;
# ...

# %%
dados['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
sns.boxplot(dados['SepalLengthCm']);
# Out:
# C:\Users\Vithep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
