# %% [markdown]
# # Analise Exploratoria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Dados/matches.csv')
df.head()
# Out:
#    id  season       city      date                        team1  \
# 0   1    2017  Hyderabad  4/5/2017          Sunrisers Hyderabad
# 1   2    2017       Pune  4/6/2017               Mumbai Indians
# 2   3    2017     Rajkot  4/7/2017                Gujarat Lions
# 3   4    2017     Indore  4/8/2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  4/8/2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# 0  normal           0          Sunrisers Hyderabad           35
# ...

# %% [markdown]
# ### Verificando valores nulos

# %%
x=df.isnull().sum()
y=(df.isnull().sum()/df.shape[0])*100
z={'Number of missing values':x,'Percentage of missing values':y}
df_1=pd.DataFrame(z,columns=['Number of missing values','Percentage of missing values'])
df_1.sort_values(by='Percentage of missing values',ascending=False)
# Out:
#                  Number of missing values  Percentage of missing values
# umpire3                               636                    100.000000
# city                                    7                      1.100629
# winner                                  3                      0.471698
# player_of_match                         3                      0.471698
# umpire2                                 1                      0.157233
# umpire1                                 1                      0.157233
# venue                                   0                      0.000000
# win_by_wickets                          0                      0.000000
# win_by_runs                             0                      0.000000
# id                                      0                      0.000000
# season                                  0                      0.000000
# result                                  0                      0.000000
# ...

# %%
x_1=df.isnull().sum(axis=1)
y_1=(x_1/df.shape[1])*100
z_1={'Number of missing values':x_1,'Percentage of missing values':y_1}
df_2=pd.DataFrame(z_1,columns=['Number of missing values','Percentage of missing values'])
df_2.sort_values(by='Percentage of missing values',ascending=False)
# Out:
#      Number of missing values  Percentage of missing values
# 545                         3                     16.666667
# 4                           3                     16.666667
# 300                         3                     16.666667
# 570                         3                     16.666667
# 469                         2                     11.111111
# ..                        ...                           ...
# 213                         1                      5.555556
# 214                         1                      5.555556
# 215                         1                      5.555556
# 216                         1                      5.555556
# 635                         1                      5.555556
#
# [636 rows x 2 columns]

# %%
df.drop(['umpire3'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2'],
#       dtype='object')

# %%
Teams={
    'Royal Challengers Bangalore':'RCB', 
    'Sunrisers Hyderabad':'SRH',
       'Rising Pune Supergiant':'RPS',
    'Mumbai Indians':'MI',
       'Kolkata Knight Riders':'KKR', 
    'Gujarat Lions':'GL',
    'Kings XI Punjab':'KXIP',
       'Delhi Daredevils':'DD',
    'Chennai Super Kings':'CSK',
    'Rajasthan Royals':'RR',
       'Deccan Chargers':'DC',
    'Kochi Tuskers Kerala':'KTK',
    'Pune Warriors':'PW',
       'Rising Pune Supergiants':'RPS'
}

# %%
df['team1']=df['team1'].map(Teams)
df['team2']=df['team2'].map(Teams)
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
print('Total de partidas:',df.shape[0])
print(' \n Cidades:',df['city'].unique())     
print(' \n Times :',df['team1'].unique())
# Out:
# Total de partidas: 636
#
#  Cidades: ['Hyderabad' 'Pune' 'Rajkot' 'Indore' 'Bangalore' 'Mumbai' 'Kolkata'
#  'Delhi' 'Chandigarh' 'Kanpur' 'Jaipur' 'Chennai' 'Cape Town'
#  'Port Elizabeth' 'Durban' 'Centurion' 'East London' 'Johannesburg'
#  'Kimberley' 'Bloemfontein' 'Ahmedabad' 'Cuttack' 'Nagpur' 'Dharamsala'
#  'Kochi' 'Visakhapatnam' 'Raipur' 'Ranchi' 'Abu Dhabi' 'Sharjah' nan]
#
#  Times : ['SRH' 'MI' 'GL' 'RPS' 'RCB' 'KKR' 'DD' 'KXIP' 'CSK' 'RR' 'DC' 'KTK' 'PW']

# %% [markdown]
# ### Os jogadores com mais premios

# %%
print(df['player_of_match'].value_counts()[:10])
# Out:
# CH Gayle          18
# YK Pathan         16
# AB de Villiers    15
# DA Warner         15
# SK Raina          14
# RG Sharma         14
# MS Dhoni          13
# G Gambhir         13
# AM Rahane         12
# MEK Hussey        12
# Name: player_of_match, dtype: int64

# %% [markdown]
# ### Valor maximo por corrida

# %%
df[df['win_by_runs']==df['win_by_runs'].max()]
# Out:
#     id  season   city      date team1 team2       toss_winner toss_decision  \
# 43  44    2017  Delhi  5/6/2017    MI    DD  Delhi Daredevils         field
#
#     result  dl_applied          winner  win_by_runs  win_by_wickets  \
# 43  normal           0  Mumbai Indians          146               0
#
#    player_of_match             venue      umpire1    umpire2
# 43     LMP Simmons  Feroz Shah Kotla  Nitin Menon  CK Nandan

# %% [markdown]
# ### Maiores vencedores por wickets

# %%
df[df['win_by_wickets']==df['win_by_wickets'].max()]
# Out:
#       id  season        city       date team1 team2  \
# 2      3    2017      Rajkot   4/7/2017    GL   KKR
# 34    35    2017  Chandigarh  4/30/2017    DD  KXIP
# 71    72    2008      Mumbai  4/27/2008    MI    DC
# 119  120    2009   Cape Town  4/19/2009  KXIP    DD
# 183  184    2010   Bangalore  3/18/2010    RR   RCB
# 298  299    2011      Mumbai  5/20/2011    MI    RR
# 376  377    2012      Jaipur  5/20/2012    RR    MI
# 390  391    2013  Chandigarh  4/10/2013  KXIP   CSK
# 542  543    2015       Delhi  4/26/2015    DD   RCB
# 590  591    2016      Rajkot  4/21/2016    GL   SRH
#
#                      toss_winner toss_decision  result  dl_applied  \
# 2          Kolkata Knight Riders         field  normal           0
# 34               Kings XI Punjab         field  normal           0
# 71               Deccan Chargers         field  normal           0
# 119             Delhi Daredevils         field  normal           1
# ...

# %%
# configurar a visualização
#%matplotlib inline
# %config InlineBackend.figure_format = 'svg'
#configurando parâmetros das fontes
plt.rcParams['font.family'] = 'sans-serif'

# %% [markdown]
# #### Decisões entre Temporadas

# %%
plt.figure(figsize=(11,6))
sns.countplot(x='season',hue='toss_decision',data=df)
plt.savefig('Imagem/IPL_1.png')

# %% [markdown]
# ### Maiores vencedores

# %%
plt.figure(figsize=(11,6))
df['toss_winner'].value_counts().plot(kind='bar');

# %% [markdown]
# ### Total de Partidas x Vitorias do Time

# %%
df.shape
# Out:
# (636, 17)

# %%
df.head()
# Out:
#    id  season       city      date team1 team2                  toss_winner  \
# 0   1    2017  Hyderabad  4/5/2017   SRH   RCB  Royal Challengers Bangalore
# 1   2    2017       Pune  4/6/2017    MI   RPS       Rising Pune Supergiant
# 2   3    2017     Rajkot  4/7/2017    GL   KKR        Kolkata Knight Riders
# 3   4    2017     Indore  4/8/2017   RPS  KXIP              Kings XI Punjab
# 4   5    2017  Bangalore  4/8/2017   RCB    DD  Royal Challengers Bangalore
#
#   toss_decision  result  dl_applied                       winner  win_by_runs  \
# 0         field  normal           0          Sunrisers Hyderabad           35
# 1         field  normal           0       Rising Pune Supergiant            0
# 2         field  normal           0        Kolkata Knight Riders            0
# 3         field  normal           0              Kings XI Punjab            0
# 4           bat  normal           0  Royal Challengers Bangalore           15
#
# ...

# %%
df.team2
# Out:
# 0       RCB
# 1       RPS
# 2       KKR
# 3      KXIP
# 4        DD
#        ...
# 631     RCB
# 632     RCB
# 633     KKR
# 634     SRH
# 635     RCB
# Name: team2, Length: 636, dtype: object

# %%
matches_played_byteams=pd.concat([df['team1'],df['team2']],axis=1)
matches_played_byteams
# Out:
#     team1 team2
# 0     SRH   RCB
# 1      MI   RPS
# 2      GL   KKR
# 3     RPS  KXIP
# 4     RCB    DD
# ..    ...   ...
# 631    DD   RCB
# 632    GL   RCB
# 633   SRH   KKR
# 634    GL   SRH
# 635   SRH   RCB
#
# [636 rows x 2 columns]

# %%
teams=(matches_played_byteams['team1'].value_counts()+matches_played_byteams['team2'].value_counts()).reset_index()
teams.columns=['team_name','Matches_played']
teams
# Out:
#    team_name  Matches_played
# 0        CSK             131
# 1         DC              75
# 2         DD             147
# 3         GL              30
# 4        KKR             148
# 5        KTK              14
# 6       KXIP             148
# 7         MI             157
# 8         PW              46
# 9        RCB             152
# 10       RPS              30
# 11        RR             118
# 12       SRH              76

# %%
df['winner']=df['winner'].map(Teams)

# %%
wins=pd.DataFrame(df['winner'].value_counts()).reset_index()
wins.columns=['team_name','wins']
wins
# Out:
#    team_name  wins
# 0         MI    92
# 1        CSK    79
# 2        KKR    77
# 3        RCB    73
# 4       KXIP    70
# 5         RR    63
# 6         DD    62
# 7        SRH    42
# 8         DC    29
# 9        RPS    15
# 10        GL    13
# 11        PW    12
# 12       KTK     6

# %%
player=teams.merge(wins,left_on='team_name',right_on='team_name',how='inner')

# %%
player.columns=['team','matches_played','wins']
player
# Out:
#     team  matches_played  wins
# 0    CSK             131    79
# 1     DC              75    29
# 2     DD             147    62
# 3     GL              30    13
# 4    KKR             148    77
# 5    KTK              14     6
# 6   KXIP             148    70
# 7     MI             157    92
# 8     PW              46    12
# 9    RCB             152    73
# 10   RPS              30    15
# 11    RR             118    63
# 12   SRH              76    42

# %%
player['%win']=(player['wins']/player['matches_played'])*100
player
# Out:
#     team  matches_played  wins       %win
# 0    CSK             131    79  60.305344
# 1     DC              75    29  38.666667
# 2     DD             147    62  42.176871
# 3     GL              30    13  43.333333
# 4    KKR             148    77  52.027027
# 5    KTK              14     6  42.857143
# 6   KXIP             148    70  47.297297
# 7     MI             157    92  58.598726
# 8     PW              46    12  26.086957
# 9    RCB             152    73  48.026316
# 10   RPS              30    15  50.000000
# 11    RR             118    63  53.389831
# 12   SRH              76    42  55.263158

# %% [markdown]
# ### Jogos por temporada

# %%
plt.figure(figsize=(11,6))
sns.countplot(df['season']);
# Out:
# C:\Users\Vithep\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
